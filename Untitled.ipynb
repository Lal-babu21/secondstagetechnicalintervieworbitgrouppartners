# %%
import pandas as pd
import numpy as np

# %%
import pyodbc

# %%
with pyodbc.connect(conn_string) as con:
    cur=con.cursor()
    cur.execute("select * from rawperformancedata")
    data =cursor.fetchall()

# %%
df = pd.DataFrame.from_records(data,columns=['UserID',
                                             'Category',
                                             'EventDate',
                                             'NumberCallsType1',
                                             'NumberCallsType2',
                                             'SalesType1', 'SalesType2',
                                             'SalesType3', 'SalesType4',
                                             'SalesType5', 'SalesType6',
                                             'CallTimeType1', 'CallTimeType2',
                                             'CallTimeType3', 'CallTimeType4',
                                             'CallTimeType5', 'CallTimeType6',
                                             'CallTimeType7', 'CallTimeType8',
                                             'CallTimeType9','TotalTimeinCall',
                                            'TotalSalesUnits','TotalNumberofCallsHandled',
                                            'AverageHandleTime','SalesPerCall','Catgry'])

# %%
df.shape
# Out:
# (146945, 26)

# %%
df.head()
# Out:
#    UserID  Category   EventDate  NumberCallsType1  NumberCallsType2  \
# 0  107046      5745  2022-10-22               1.0               0.0
# 1  104873        -1  2022-09-12               NaN               NaN
# 2  104859      5910  2022-08-22               2.0               0.0
# 3  105436        -1  2022-10-31               NaN               NaN
# 4  105125        -1  2022-08-13               NaN               NaN
#
#    SalesType1  SalesType2  SalesType3  SalesType4  SalesType5  ...  \
# 0         NaN         NaN         0.0         0.0         0.0  ...
# 1         NaN         NaN         0.0         0.0         0.0  ...
# 2         NaN         NaN         0.0         0.0         0.0  ...
# 3         1.0         NaN         0.0         0.0         1.0  ...
# 4         NaN         NaN         0.0         0.0         0.0  ...
#
#    CallTimeType6  CallTimeType7  CallTimeType8  CallTimeType9  \
# 0            0.0            0.0            0.0            0.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 146945 entries, 0 to 146944
# Data columns (total 26 columns):
#  #   Column                     Non-Null Count   Dtype
# ---  ------                     --------------   -----
#  0   UserID                     146945 non-null  int64
#  1   Category                   146945 non-null  int64
#  2   EventDate                  146945 non-null  object
#  3   NumberCallsType1           99343 non-null   float64
#  4   NumberCallsType2           99343 non-null   float64
#  5   SalesType1                 7351 non-null    float64
#  6   SalesType2                 9667 non-null    float64
#  7   SalesType3                 146945 non-null  float64
#  8   SalesType4                 146945 non-null  float64
#  9   SalesType5                 146945 non-null  float64
#  10  SalesType6                 146945 non-null  float64
#  11  CallTimeType1              99343 non-null   float64
#  12  CallTimeType2              99343 non-null   float64
# ...

# %%
df.to_excel("rawperformancedata.xlsx")
